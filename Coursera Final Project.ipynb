# %% [markdown]
# This notebook will be used for the capstone project of IBM's Applied Data Science Capstone.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Final Project!")
# Out:
# Hello Capstone Final Project!
